# %%
import os
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import gc

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
SIZE = 180
EPOCHS = 10
BATCH_SIZE = 32
FOLDS = 8

beningList1 = os.listdir('/content/drive/MyDrive/skincancer/data/test/benign')
beningList2 = os.listdir('/content/drive/MyDrive/skincancer/data/train/benign')

malignantList1 = os.listdir('/content/drive/MyDrive/skincancer/data/test/malignant')
malignantList2 = os.listdir('/content/drive/MyDrive/skincancer/data/train/malignant')

# %%
from cv2 import imread, resize

def create_dataset(x, y, path, files, type_):
    for i in range(len(files)):
        img = imread(path + files[i])
        x.append(resize(img, (SIZE, SIZE)))
        y.append(type_)

# %%
from sklearn.utils.class_weight import compute_class_weight
from keras.utils.np_utils import to_categorical

X = []
y = []
#create_dataset(X, y, '../input/data/test/benign/', beningList1, 0)
create_dataset(X, y, '/content/drive/MyDrive/skincancer/data/train/benign/', beningList2, 0)
create_dataset(X, y, '/content/drive/MyDrive/skincancer/data/test/benign/', beningList1, 0)
#create_dataset(X, y, '../input/data/test/malignant/', malignantList1, 1)
create_dataset(X, y, '/content/drive/MyDrive/skincancer/data/train/malignant/', malignantList2, 1)
create_dataset(X, y, '/content/drive/MyDrive/skincancer/data/test/malignant/', malignantList1, 1)
X = np.array(X)
y = np.array(y)
y_train = to_categorical(y, num_classes=2)

class_weights = np.around(compute_class_weight(class_weight='balanced', classes=np.unique(y_train), y=y), 2)
class_weights = dict(zip(np.unique(y_train), class_weights))
print('balancing classes: ',class_weights)
print(X.shape)
print(y_train.shape)
# Out:
# balancing classes:  {0.0: 0.92, 1.0: 1.1}
# (3297, 180, 180, 3)
# (3297, 2)

# %%
import tensorflow as tf
from tensorflow.keras import layers
from keras.callbacks import EarlyStopping,ModelCheckpoint
from tensorflow.keras.optimizers import Adam

early_stopping = EarlyStopping(monitor='val_accuracy',
                               mode='max',
                               patience=10)

def create_model():
    pre_trained_model = tf.keras.applications.ResNet152V2(include_top=False,
                                                        input_shape=(SIZE, SIZE, 3),
                                                        weights='imagenet')

    optimizer = Adam(learning_rate=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-3)

    print('layers ',len(pre_trained_model.layers))

    for layer in pre_trained_model.layers[:8]:
        layer.trainable = False
    for layer in pre_trained_model.layers[9:]:
        layer.trainable = True

    model = tf.keras.models.Sequential([
        pre_trained_model,
        layers.Conv2D(64, (3, 3), activation='relu'),
        layers.Conv2D(64, (3, 3), activation='relu'),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Flatten(),
        layers.Dense(4096, activation='relu'),
        layers.Dropout(0.5),
        layers.Dense(4096, activation='relu'),
        layers.Dropout(0.5),
        layers.Dense(2, activation='softmax')
    ])

    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    model.summary()
    return model

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import StratifiedKFold

i=0
model_history = [] 
skf = StratifiedKFold(n_splits=FOLDS, random_state=None, shuffle=False)
model = None
filepath = 'best_resnet152_fold_unique.h5'
checkpoint = ModelCheckpoint(filepath,
             monitor='val_accuracy',
             mode='max',
             save_best_only=True,
             verbose=1)
model = create_model()

for train_index, val_index in skf.split(X,y):
    print('*****Starting fold ', i+1, ' of ', FOLDS)
    X_train, X_test, y_train, y_test = X[train_index], X[val_index],y[train_index], y[val_index]
    y_train = to_categorical(y_train, num_classes=2)
    y_test = to_categorical(y_test, num_classes=2)
    datagen = ImageDataGenerator(shear_range=0.2,
                                 zoom_range=0.2,
                                 rotation_range=40,
                                 brightness_range=(0.5, 1.5),
                                 vertical_flip=True,
                                 horizontal_flip=True)
    datagen.fit(X_train)
    model_history.append(model.fit(datagen.flow(X_train, y_train), epochs=EPOCHS, batch_size=BATCH_SIZE, shuffle=True,
                          callbacks=[early_stopping, checkpoint],
                          validation_data=(X_test, y_test),
                          class_weight=class_weights))
    print('*****Finishing fold ', i+1, ' of ', FOLDS)
    i = i+1
    gc.collect()
# Out:
# layers  564
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet152v2 (Functional)    (None, 6, 6, 2048)        58331648
#
#  conv2d (Conv2D)             (None, 4, 4, 64)          1179712
#
#  conv2d_1 (Conv2D)           (None, 2, 2, 64)          36928
#
#  max_pooling2d_3 (MaxPooling  (None, 1, 1, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 64)                0
#
#  dense (Dense)               (None, 4096)              266240
#
#  dropout (Dropout)           (None, 4096)              0
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  dropout_1 (Dropout)         (None, 4096)              0
#
#  dense_2 (Dense)             (None, 2)                 8194
#
# =================================================================
# Total params: 76,604,034
# Trainable params: 76,446,594
# Non-trainable params: 157,440
# _________________________________________________________________
# *****Starting fold  1  of  8
# Epoch 1/10
# 91/91 [==============================] - ETA: 0s - loss: 0.5802 - accuracy: 0.6800
# Epoch 00001: val_accuracy improved from -inf to 0.63680, saving model to best_resnet152_fold_unique.h5
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# 91/91 [==============================] - 89s 671ms/step - loss: 0.5802 - accuracy: 0.6800 - val_loss: 0.7048 - val_accuracy: 0.6368
# Epoch 2/10
# 91/91 [==============================] - ETA: 0s - loss: 0.3850 - accuracy: 0.8256
# Epoch 00002: val_accuracy improved from 0.63680 to 0.76271, saving model to best_resnet152_fold_unique.h5
# 91/91 [==============================] - 58s 635ms/step - loss: 0.3850 - accuracy: 0.8256 - val_loss: 0.4768 - val_accuracy: 0.7627
# Epoch 3/10
# 91/91 [==============================] - ETA: 0s - loss: 0.3332 - accuracy: 0.8436
# Epoch 00003: val_accuracy improved from 0.76271 to 0.80872, saving model to best_resnet152_fold_unique.h5
# 91/91 [==============================] - 58s 632ms/step - loss: 0.3332 - accuracy: 0.8436 - val_loss: 0.4223 - val_accuracy: 0.8087
# Epoch 4/10
# 91/91 [==============================] - ETA: 0s - loss: 0.3315 - accuracy: 0.8391
# Epoch 00004: val_accuracy did not improve from 0.80872
# 91/91 [==============================] - 54s 589ms/step - loss: 0.3315 - accuracy: 0.8391 - val_loss: 0.4087 - val_accuracy: 0.7869
# Epoch 5/10
# 91/91 [==============================] - ETA: 0s - loss: 0.3101 - accuracy: 0.8474
# Epoch 00005: val_accuracy improved from 0.80872 to 0.81840, saving model to best_resnet152_fold_unique.h5
# 91/91 [==============================] - 58s 634ms/step - loss: 0.3101 - accuracy: 0.8474 - val_loss: 0.3667 - val_accuracy: 0.8184
# Epoch 6/10
# 91/91 [==============================] - ETA: 0s - loss: 0.3039 - accuracy: 0.8575
# Epoch 00006: val_accuracy did not improve from 0.81840
# 91/91 [==============================] - 53s 582ms/step - loss: 0.3039 - accuracy: 0.8575 - val_loss: 0.4180 - val_accuracy: 0.7942
# Epoch 7/10
# 91/91 [==============================] - ETA: 0s - loss: 0.2950 - accuracy: 0.8613
# Epoch 00007: val_accuracy improved from 0.81840 to 0.83293, saving model to best_resnet152_fold_unique.h5
# 91/91 [==============================] - 58s 636ms/step - loss: 0.2950 - accuracy: 0.8613 - val_loss: 0.3459 - val_accuracy: 0.8329
# Epoch 8/10
# 91/91 [==============================] - ETA: 0s - loss: 0.3077 - accuracy: 0.8495
# Epoch 00008: val_accuracy did not improve from 0.83293
# 91/91 [==============================] - 53s 584ms/step - loss: 0.3077 - accuracy: 0.8495 - val_loss: 0.4076 - val_accuracy: 0.8087
# Epoch 9/10
# 91/91 [==============================] - ETA: 0s - loss: 0.2859 - accuracy: 0.8658
# Epoch 00009: val_accuracy did not improve from 0.83293
# 91/91 [==============================] - 53s 578ms/step - loss: 0.2859 - accuracy: 0.8658 - val_loss: 0.3141 - val_accuracy: 0.8257
# Epoch 10/10
# 91/91 [==============================] - ETA: 0s - loss: 0.2801 - accuracy: 0.8776
# Epoch 00010: val_accuracy improved from 0.83293 to 0.84019, saving model to best_resnet152_fold_unique.h5
# 91/91 [==============================] - 57s 620ms/step - loss: 0.2801 - accuracy: 0.8776 - val_loss: 0.3742 - val_accuracy: 0.8402
# *****Finishing fold  1  of  8
# *****Starting fold  2  of  8
# Epoch 1/10
# 91/91 [==============================] - ETA: 0s - loss: 0.2846 - accuracy: 0.8645
# Epoch 00001: val_accuracy improved from 0.84019 to 0.91505, saving model to best_resnet152_fold_unique.h5
# 91/91 [==============================] - 59s 648ms/step - loss: 0.2846 - accuracy: 0.8645 - val_loss: 0.1867 - val_accuracy: 0.9150
# Epoch 2/10
# 91/91 [==============================] - ETA: 0s - loss: 0.2666 - accuracy: 0.8752
# Epoch 00002: val_accuracy did not improve from 0.91505
# 91/91 [==============================] - 52s 570ms/step - loss: 0.2666 - accuracy: 0.8752 - val_loss: 0.1855 - val_accuracy: 0.9126
# Epoch 3/10
# 91/91 [==============================] - ETA: 0s - loss: 0.2665 - accuracy: 0.8766
# Epoch 00003: val_accuracy improved from 0.91505 to 0.91748, saving model to best_resnet152_fold_unique.h5
# 91/91 [==============================] - 56s 618ms/step - loss: 0.2665 - accuracy: 0.8766 - val_loss: 0.1798 - val_accuracy: 0.9175
# Epoch 4/10
# 91/91 [==============================] - ETA: 0s - loss: 0.2581 - accuracy: 0.8749
# Epoch 00004: val_accuracy did not improve from 0.91748
# 91/91 [==============================] - 52s 570ms/step - loss: 0.2581 - accuracy: 0.8749 - val_loss: 0.1804 - val_accuracy: 0.9126
# Epoch 5/10
# 91/91 [==============================] - ETA: 0s - loss: 0.2494 - accuracy: 0.8853
# Epoch 00005: val_accuracy did not improve from 0.91748
# 91/91 [==============================] - 52s 569ms/step - loss: 0.2494 - accuracy: 0.8853 - val_loss: 0.1987 - val_accuracy: 0.9175
# Epoch 6/10
# 91/91 [==============================] - ETA: 0s - loss: 0.2511 - accuracy: 0.8832
# Epoch 00006: val_accuracy improved from 0.91748 to 0.92718, saving model to best_resnet152_fold_unique.h5
# 91/91 [==============================] - 56s 621ms/step - loss: 0.2511 - accuracy: 0.8832 - val_loss: 0.1821 - val_accuracy: 0.9272
# Epoch 7/10
# 91/91 [==============================] - ETA: 0s - loss: 0.2446 - accuracy: 0.8901
# Epoch 00007: val_accuracy did not improve from 0.92718
# 91/91 [==============================] - 53s 576ms/step - loss: 0.2446 - accuracy: 0.8901 - val_loss: 0.1947 - val_accuracy: 0.9126
# Epoch 8/10
# 91/91 [==============================] - ETA: 0s - loss: 0.2227 - accuracy: 0.9012
# Epoch 00008: val_accuracy did not improve from 0.92718
# 91/91 [==============================] - 52s 573ms/step - loss: 0.2227 - accuracy: 0.9012 - val_loss: 0.2062 - val_accuracy: 0.9150
# Epoch 9/10
# 91/91 [==============================] - ETA: 0s - loss: 0.2167 - accuracy: 0.9057
# Epoch 00009: val_accuracy did not improve from 0.92718
# 91/91 [==============================] - 53s 581ms/step - loss: 0.2167 - accuracy: 0.9057 - val_loss: 0.2115 - val_accuracy: 0.9102
# Epoch 10/10
# 91/91 [==============================] - ETA: 0s - loss: 0.2428 - accuracy: 0
of  8
# Epoch 1/10
# 91/91 [==============================] - ETA: 0s - loss: 0.1476 - accuracy: 0.9366
# Epoch 00001: val_accuracy did not improve from 0.97087
# 91/91 [==============================] - 53s 582ms/step - loss: 0.1476 - accuracy: 0.9366 - val_loss: 0.1283 - val_accuracy: 0.9490
# Epoch 2/10
# 91/91 [==============================] - ETA: 0s - loss: 0.1562 - accuracy: 0.9321
# Epoch 00002: val_accuracy did not improve from 0.97087
# 91/91 [==============================] - 53s 575ms/step - loss: 0.1562 - accuracy: 0.9321 - val_loss: 0.1670 - val_accuracy: 0.9320
# Epoch 3/10
# 91/91 [==============================] - ETA: 0s - loss: 0.1631 - accuracy: 0.9373
# Epoch 00003: val_accuracy did not improve from 0.97087
# 91/91 [==============================] - 52s 573ms/step - loss: 0.1631 - accuracy: 0.9373 - val_loss: 0.1532 - val_accuracy: 0.9272
# Epoch 4/10
# 91/91 [==============================] - ETA: 0s - loss: 0.1410 - accuracy: 0.9470
# Epoch 00004: val_accuracy did not improve from 0.97087
# 91/91 [==============================] - 52s 573ms/step - loss: 0.1410 - accuracy: 0.9470 - val_loss: 0.1315 - val_accuracy: 0.9393
# Epoch 5/10
# 91/91 [==============================] - ETA: 0s - loss: 0.1318 - accuracy: 0.9487
# Epoch 00005: val_accuracy did not improve from 0.97087
# 91/91 [==============================] - 52s 573ms/step - loss: 0.1318 - accuracy: 0.9487 - val_loss: 0.1211 - val_accuracy: 0.9393
# Epoch 6/10
# 91/91 [==============================] - ETA: 0s - loss: 0.1575 - accuracy: 0.9362
# Epoch 00006: val_accuracy did not improve from 0.97087
# 91/91 [==============================] - 52s 573ms/step - loss: 0.1575 - accuracy: 0.9362 - val_loss: 0.1431 - val_accuracy: 0.9442
# Epoch 7/10
# 91/91 [==============================] - ETA: 0s - loss: 0.1351 - accuracy: 0.9466
# Epoch 00007: val_accuracy did not improve from 0.97087
# 91/91 [==============================] - 52s 573ms/step - loss: 0.1351 - accuracy: 0.9466 - val_loss: 0.1854 - val_accuracy: 0.9320
# Epoch 8/10
# 91/91 [==============================] - ETA: 0s - loss: 0.1165 - accuracy: 0.9549
# Epoch 00008: val_accuracy did not improve from 0.97087
# 91/91 [==============================] - 53s 582ms/step - loss: 0.1165 - accuracy: 0.9549 - val_loss: 0.1935 - val_accuracy: 0.9248
# Epoch 9/10
# 91/91 [==============================] - ETA: 0s - loss: 0.1140 - accuracy: 0.9484
# Epoch 00009: val_accuracy did not improve from 0.97087
# 91/91 [==============================] - 53s 576ms/step - loss: 0.1140 - accuracy: 0.9484 - val_loss: 0.1875 - val_accuracy: 0.9199
# Epoch 10/10
# 91/91 [==============================] - ETA: 0s - loss: 0.1827 - accuracy: 0.9300
# Epoch 00010: val_accuracy did not improve from 0.97087
# 91/91 [==============================] - 53s 575ms/step - loss: 0.1827 - accuracy: 0.9300 - val_loss: 0.1768 - val_accuracy: 0.9102
# *****Finishing fold  5  of  8
# *****Starting fold  6  of  8
# Epoch 1/10
# 91/91 [==============================] - ETA: 0s - loss: 0.1391 - accuracy: 0.9421
# Epoch 00001: val_accuracy did not improve from 0.97087
# 91/91 [==============================] - 53s 575ms/step - loss: 0.1391 - accuracy: 0.9421 - val_loss: 0.1438 - val_accuracy: 0.9345
# Epoch 2/10
# 91/91 [==============================] - ETA: 0s - loss: 0.1300 - accuracy: 0.9508
# Epoch 00002: val_accuracy did not improve from 0.97087
# 91/91 [==============================] - 52s 573ms/step - loss: 0.1300 - accuracy: 0.9508 - val_loss: 0.1536 - val_accuracy: 0.9417
# Epoch 3/10
# 91/91 [==============================] - ETA: 0s - loss: 0.1413 - accuracy: 0.9418
# Epoch 00003: val_accuracy did not improve from 0.97087
# 91/91 [==============================] - 53s 583ms/step - loss: 0.1413 - accuracy: 0.9418 - val_loss: 0.1206 - val_accuracy: 0.9442
# Epoch 4/10
# 91/91 [==============================] - ETA: 0s - loss: 0.1115 - accuracy: 0.9536
# Epoch 00004: val_accuracy did not improve from 0.97087
# 91/91 [==============================] - 53s 576ms/step - loss: 0.1115 - accuracy: 0.9536 - val_loss: 0.1731 - val_accuracy: 0.9417

# %%
#plt.title('Val Accuracies vs Epochs')
for i in range(FOLDS):
    plt.plot(model_history[i].history['val_accuracy'], label='Training Fold '+str(i+1))
plt.legend()
plt.show()

# %%
#plt.title('Val Accuracies vs Epochs')
#for i in range(FOLDS):
    #plt.plot(model_history[i].history['val_accuracy'], label='Training Fold '+str(i+1))
#plt.legend()
#plt.show()

# %%
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, roc_auc_score
import seaborn as sns

target_names = ['benign', 'malignant']

X = []
y = []
create_dataset(X, y, '/content/drive/MyDrive/skincancer/data/test/benign', beningList1, 0)
create_dataset(X, y, '/content/drive/MyDrive/skincancer/data/test/benign', beningList2, 0)
create_dataset(X, y, '/content/drive/MyDrive/skincancer/data/test/malignant/', malignantList1, 1)
create_dataset(X, y, '/content/drive/MyDrive/skincancer/data/test/malignant/', malignantList2, 1)
roc_curves = []
X = np.array(X)
y_true = np.array(y)
y_expected = to_categorical(y_true, num_classes=2)
best_model = None
print('evaluating: ','best_mobilenet_fold_unique.h5')
result = model.evaluate(X, y_expected)
y_pred = model.predict(X)
y_pred = np.argmax(y_pred, axis=1)
print('Classification Report:')
print(classification_report(y_true, y_pred, target_names=target_names))
print('Confusion Matrix:')
y_true_as_label = ['benign' if (i == 0) else 'malignant'  for i in y_true]
y_pred_as_label = ['benign' if (i == 0) else 'malignant'  for i in y_pred]
cm = confusion_matrix(y_true_as_label, y_pred_as_label, labels=target_names)
ax = plt.subplot()
sns.heatmap(cm, annot=True, fmt='g', ax=ax)
ax.xaxis.set_ticklabels(target_names)
ax.yaxis.set_ticklabels(target_names)
plt.show()
fpr, tpr, thresholds  = roc_curve(y_true,y_pred)
auc = roc_auc_score(y_true, y_pred)
print('ROC AUC score:', auc)
print('-----------------------------------')

# %%
plt.plot(fpr, tpr, linestyle='--', label='Model: best_resnet152_fold_unique.h5')

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
# show the legend
plt.legend()
# show the plot
plt.show()
